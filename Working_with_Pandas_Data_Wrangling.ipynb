# %% [markdown]
# <a href="https://colab.research.google.com/github/mathewdavid/maths_data_science/blob/main/Working_with_Pandas_Data_Wrangling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# #Reading the Data

# %%
Cu_df = pd.read_csv('Customers.csv')

# %%
Cu_df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0           1    Male   19              15000                      39
# 1           2    Male   21              35000                      81
# 2           3  Female   20              86000                       6
# 3           4  Female   23              59000                      77
# 4           5  Female   31              38000                      40
#
#       Profession  Work Experience  Family Size
# 0     Healthcare                1            4
# 1       Engineer                3            3
# 2       Engineer                1            1
# 3         Lawyer                0            2
# 4  Entertainment                2            6

# %%
Cu_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              2000 non-null   int64
#  1   Gender                  2000 non-null   object
#  2   Age                     2000 non-null   int64
#  3   Annual Income ($)       2000 non-null   int64
#  4   Spending Score (1-100)  2000 non-null   int64
#  5   Profession              1965 non-null   object
#  6   Work Experience         2000 non-null   int64
#  7   Family Size             2000 non-null   int64
# dtypes: int64(6), object(2)
# memory usage: 125.1+ KB

# %%
Cu_df.describe()
# Out:
#         CustomerID          Age  Annual Income ($)  Spending Score (1-100)  \
# count  2000.000000  2000.000000        2000.000000             2000.000000
# mean   1000.500000    48.960000      110731.821500               50.962500
# std     577.494589    28.429747       45739.536688               27.934661
# min       1.000000     0.000000           0.000000                0.000000
# 25%     500.750000    25.000000       74572.000000               28.000000
# 50%    1000.500000    48.000000      110045.000000               50.000000
# 75%    1500.250000    73.000000      149092.750000               75.000000
# max    2000.000000    99.000000      189974.000000              100.000000
#
#        Work Experience  Family Size
# count      2000.000000  2000.000000
# mean          4.102500     3.768500
# std           3.922204     1.970749
# min           0.000000     1.000000
# 25%           1.000000     2.000000
# 50%           3.000000     4.000000
# ...

# %% [markdown]
# # Working with missing values

# %%
Cu_df.isnull()
# Out:
#       CustomerID  Gender    Age  Annual Income ($)  Spending Score (1-100)  \
# 0          False   False  False              False                   False
# 1          False   False  False              False                   False
# 2          False   False  False              False                   False
# 3          False   False  False              False                   False
# 4          False   False  False              False                   False
# ...          ...     ...    ...                ...                     ...
# 1995       False   False  False              False                   False
# 1996       False   False  False              False                   False
# 1997       False   False  False              False                   False
# 1998       False   False  False              False                   False
# 1999       False   False  False              False                   False
#
#       Profession  Work Experience  Family Size
# ...

# %%
Cu_df.isnull().sum()
# Out:
# CustomerID                 0
# Gender                     0
# Age                        0
# Annual Income ($)          0
# Spending Score (1-100)     0
# Profession                35
# Work Experience            0
# Family Size                0
# dtype: int64

# %%
Cu_df['Profession']
# Out:
# 0          Healthcare
# 1            Engineer
# 2            Engineer
# 3              Lawyer
# 4       Entertainment
#             ...
# 1995           Artist
# 1996           Doctor
# 1997       Healthcare
# 1998        Executive
# 1999    Entertainment
# Name: Profession, Length: 2000, dtype: object

# %%
Cu_df.dropna(how='any',inplace=True)

# %%
Cu_df.describe()
# Out:
#         CustomerID          Age  Annual Income ($)  Spending Score (1-100)  \
# count  1965.000000  1965.000000        1965.000000             1965.000000
# mean   1000.309924    48.894656      110616.009669               51.078880
# std     578.443714    28.414889       45833.860195               27.977176
# min       1.000000     0.000000           0.000000                0.000000
# 25%     498.000000    25.000000       74350.000000               28.000000
# 50%    1000.000000    48.000000      109759.000000               50.000000
# 75%    1502.000000    73.000000      149095.000000               75.000000
# max    2000.000000    99.000000      189974.000000              100.000000
#
#        Work Experience  Family Size
# count      1965.000000  1965.000000
# mean          4.092621     3.757252
# std           3.926459     1.968335
# min           0.000000     1.000000
# 25%           1.000000     2.000000
# 50%           3.000000     4.000000
# ...

# %%
Cu_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1965 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              1965 non-null   int64
#  1   Gender                  1965 non-null   object
#  2   Age                     1965 non-null   int64
#  3   Annual Income ($)       1965 non-null   int64
#  4   Spending Score (1-100)  1965 non-null   int64
#  5   Profession              1965 non-null   object
#  6   Work Experience         1965 non-null   int64
#  7   Family Size             1965 non-null   int64
# dtypes: int64(6), object(2)
# memory usage: 138.2+ KB

# %%
Cu_df['Age'].mean()
# Out:
# 48.89465648854962

# %%
Cu_df['Gender']
# Out:
# 0         Male
# 1         Male
# 2       Female
# 3       Female
# 4       Female
#          ...
# 1995    Female
# 1996    Female
# 1997      Male
# 1998      Male
# 1999      Male
# Name: Gender, Length: 1965, dtype: object

# %% [markdown]
# # Performing one hot encoding

# %%
bi_gen = pd.get_dummies(Cu_df['Gender'])
print(bi_gen)
# Out:
#       Female  Male
# 0          0     1
# 1          0     1
# 2          1     0
# 3          1     0
# 4          1     0
# ...      ...   ...
# 1995       1     0
# 1996       1     0
# 1997       0     1
# 1998       0     1
# 1999       0     1
#
# [1965 rows x 2 columns]

# %%
cus_df = pd.read_csv('Customers.csv')

# %%
cus_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              2000 non-null   int64
#  1   Gender                  2000 non-null   object
#  2   Age                     2000 non-null   int64
#  3   Annual Income ($)       2000 non-null   int64
#  4   Spending Score (1-100)  2000 non-null   int64
#  5   Profession              1965 non-null   object
#  6   Work Experience         2000 non-null   int64
#  7   Family Size             2000 non-null   int64
# dtypes: int64(6), object(2)
# memory usage: 125.1+ KB

# %%
Cu_df
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# ...

# %%
Cu_df['Profession'].unique()
# Out:
# array(['Healthcare', 'Engineer', 'Lawyer', 'Entertainment', 'Artist',
#        'Executive', 'Doctor', 'Homemaker', 'Marketing'], dtype=object)

# %% [markdown]
# # Performing Scaling (Normalization and Standardisation)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
Cu_df['Age']=scaler.fit_transform(Cu_df['Age'].values.reshape(-1,1))

# %%
Cu_df['Age']
# Out:
# 0       0.191919
# 1       0.212121
# 2       0.202020
# 3       0.232323
# 4       0.313131
#           ...
# 1995    0.717172
# 1996    0.919192
# 1997    0.878788
# 1998    0.777778
# 1999    0.909091
# Name: Age, Length: 1965, dtype: float64

# %%
Cu_df.describe().round(2)
# Out:
#        CustomerID      Age  Annual Income ($)  Spending Score (1-100)  \
# count     1965.00  1965.00            1965.00                 1965.00
# mean      1000.31     0.49          110616.01                   51.08
# std        578.44     0.29           45833.86                   27.98
# min          1.00     0.00               0.00                    0.00
# 25%        498.00     0.25           74350.00                   28.00
# 50%       1000.00     0.48          109759.00                   50.00
# 75%       1502.00     0.74          149095.00                   75.00
# max       2000.00     1.00          189974.00                  100.00
#
#        Work Experience  Family Size
# count          1965.00      1965.00
# mean              4.09         3.76
# std               3.93         1.97
# min               0.00         1.00
# 25%               1.00         2.00
# 50%               3.00         4.00
# 75%               7.00         5.00
# max              17.00         9.00

# %%
#Standardization

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
Cu_df['Age']=scaler.fit_transform(Cu_df['Age'].values.reshape(-1,1))
Cu_df['Age']
# Out:
# 0      -1.052345
# 1      -0.981941
# 2      -1.017143
# 3      -0.911538
# 4      -0.629924
#           ...
# 1995    0.778147
# 1996    1.482183
# 1997    1.341376
# 1998    0.989358
# 1999    1.446981
# Name: Age, Length: 1965, dtype: float64

# %%
Cu_df.describe().round(2)
# Out:
#        CustomerID      Age  Annual Income ($)  Spending Score (1-100)  \
# count     1965.00  1965.00            1965.00                 1965.00
# mean      1000.31     0.00          110616.01                   51.08
# std        578.44     1.00           45833.86                   27.98
# min          1.00    -1.72               0.00                    0.00
# 25%        498.00    -0.84           74350.00                   28.00
# 50%       1000.00    -0.03          109759.00                   50.00
# 75%       1502.00     0.85          149095.00                   75.00
# max       2000.00     1.76          189974.00                  100.00
#
#        Work Experience  Family Size
# count          1965.00      1965.00
# mean              4.09         3.76
# std               3.93         1.97
# min               0.00         1.00
# 25%               1.00         2.00
# 50%               3.00         4.00
# 75%               7.00         5.00
# max              17.00         9.00

# %%
cus_df
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# ...

# %% [markdown]
# # Filtering with Pandas

# %%
medical_profession_df = cus_df[(cus_df['Profession']=='Healthcare')]
medical_profession_df
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 6              7  Female   35              31000                       6
# 7              8  Female   23              84000                      94
# 11            12  Female   35              93000                      99
# 15            16    Male   22              51000                      79
# ...          ...     ...  ...                ...                     ...
# 1930        1931    Male   72             182317                      46
# 1942        1943  Female   55              66728                      50
# 1949        1950    Male   37             102413                      38
# 1974        1975  Female   14             153145                      59
# 1997        1998    Male   87              90961                      14
#
#       Profession  Work Experience  Family Size
# ...

# %%
cond_1 = cus_df['Age']>=40
cond_2 = cus_df['Profession']=='Healthcare'

exp_doc_df = cus_df[cond_1 & cond_2]
exp_doc_df
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 26            27  Female   45              68000                      32
# 32            33    Male   53              59000                       4
# 56            57  Female   51              71000                      50
# 70            71    Male   70              91000                      55
# 73            74  Female   60              10000                      56
# ...          ...     ...  ...                ...                     ...
# 1920        1921    Male   46             137973                      50
# 1927        1928    Male   77             151985                      29
# 1930        1931    Male   72             182317                      46
# 1942        1943  Female   55              66728                      50
# 1997        1998    Male   87              90961                      14
#
#       Profession  Work Experience  Family Size
# ...

# %% [markdown]
# # Downloading filtered file

# %%
#Downloading filtered CSV
exp_doc_df.to_csv('HealthcareExp.csv')

# %% [markdown]
# # Performing Basic EDA

# %%
cus_df
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# ...

# %%
male_df = cus_df[cus_df['Gender']=='Male']
male_df
# Out:
#       CustomerID Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1   Male   19              15000                      39
# 1              2   Male   21              35000                      81
# 8              9   Male   64              97000                       3
# 10            11   Male   67               7000                      14
# 14            15   Male   37              19000                      13
# ...          ...    ...  ...                ...                     ...
# 1987        1988   Male   63              59244                      80
# 1992        1993   Male   94             181183                      24
# 1997        1998   Male   87              90961                      14
# 1998        1999   Male   77             182109                       4
# 1999        2000   Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# 0        Healthcare                1            4
# ...

# %%
Female_df = cus_df[cus_df['Gender']=='Female']
Female_df
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# 5              6  Female   22              58000                      76
# 6              7  Female   35              31000                       6
# ...          ...     ...  ...                ...                     ...
# 1991        1992  Female   97             129444                      96
# 1993        1994  Female   64             175254                     100
# 1994        1995  Female   19              54121                      89
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
#
#          Profession  Work Experience  Family Size
# ...

# %%
male_df.describe()
# Out:
#         CustomerID         Age  Annual Income ($)  Spending Score (1-100)  \
# count   814.000000  814.000000         814.000000              814.000000
# mean   1003.649877   49.159705      110991.323096               50.944717
# std     582.563041   28.685795       45555.982548               27.808573
# min       1.000000    0.000000           0.000000                1.000000
# 25%     486.500000   24.000000       76913.750000               28.000000
# 50%    1006.500000   48.000000      108055.000000               51.000000
# 75%    1515.750000   74.000000      149536.250000               75.000000
# max    2000.000000   99.000000      189945.000000              100.000000
#
#        Work Experience  Family Size
# count       814.000000   814.000000
# mean          4.200246     3.769042
# std           3.976307     1.963561
# min           0.000000     1.000000
# 25%           1.000000     2.000000
# 50%           3.500000     4.000000
# 75%           8.000000     5.000000
# ...

# %%
Female_df.describe()
# Out:
#         CustomerID          Age  Annual Income ($)  Spending Score (1-100)  \
# count  1186.000000  1186.000000        1186.000000             1186.000000
# mean    998.338111    48.822934      110553.715008               50.974705
# std     574.226456    28.263988       45883.436382               28.032580
# min       3.000000     0.000000        1000.000000                0.000000
# 25%     507.500000    25.000000       73135.500000               28.000000
# 50%     994.500000    48.000000      111174.000000               50.000000
# 75%    1489.750000    72.000000      148733.750000               75.000000
# max    1997.000000    99.000000      189974.000000              100.000000
#
#        Work Experience  Family Size
# count      1186.000000  1186.000000
# mean          4.035413     3.768128
# std           3.884896     1.976494
# min           0.000000     1.000000
# 25%           1.000000     2.000000
# 50%           3.000000     4.000000
# ...

# %% [markdown]
# # Histogram

# %%
Cu_df['Age'].hist(bins=30, figsize=(10,10), color='r')
# Out:
# <Axes: >
